# %%
print("hello world! \n hello world!")
# Out:
# hello world!
#  hello world!

# %%
print("hello" + " world!")
# Out:
# hello world!

# %%
n = input("What is your name? ")
print("Hello, " + n + "!")
# Out:
# Hello, vivek!

# %%
print("your name has " + str(len(n)) + " characters.")
# Out:
# your name has 5 characters.

# %% [markdown]
# Camel casing capitalizes the first letter of each word after the first (e.g., userName), while snake casing uses underscores between lowercase words (e.g., user_name)

# %%
print("Welcome to the brand name generator.")
city=input("What's thename of the city you grew up in?")
pet=input("What's the name of your pet?")
print("Your brand name could be " + str(city) + " " + str(pet))
# Out:
# Welcome to the brand name generator.
# Your brand name could be city pet
