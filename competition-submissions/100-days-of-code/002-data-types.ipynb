# %%
s = "Hello, World!"
print(s)
print(s[0])
print(s[7:12])
print(s[-1])
print(s.lower())
# Out:
# Hello, World!
# H
# World
# !
# hello, world!

# %%
print(123456)
print(123_456)
# Out:
# 123456
# 123456
